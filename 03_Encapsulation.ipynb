# %% [markdown]
# ### 3. **Encapsulation**
# Encapsulation hides the internal details of an object and exposes only what is necessary.

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.__balance = balance  # Private variable

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")

    def get_balance(self):  # Public method to access private variable
        return self.__balance

account = BankAccount("John", 1000)
account.deposit(500)
print(account.get_balance())
account.withdraw(2000)  # Prints "Insufficient balance"
# Out:
# 1500
# Insufficient balance

# %% [markdown]
# - Variables prefixed with `__` are private.
# - Public methods like `get_balance()` provide controlled access to private variables.
